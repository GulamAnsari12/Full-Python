# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel ("expense3.xlsx")
df
# Out:
#          Date    Category       Sub-Category   Amount Payment Mode
# 0  2023-01-01     Grocery             Grocery      30         Cash
# 1  2023-01-02        Food          Restaurant     890          UPI
# 2  2023-01-04         123              Zomato     257          NaN
# 3  2023-01-06  Essentials               Diary     120          UPI
# 4  2023-01-06  Essentials             Perfume    1500         Cash
# 5  2023-01-09     Grocery  Fruits and Veggies     456         Cash
# 6  2023-01-10       Bills          House Rent   16000          UPI
# 7  2023-01-10     Grocery      Tomato KetchUp      70          UPI
# 8  2023-01-12        Food                Chai      15          UPI
# 9  2023-01-15  Essentials      Salt and Sugar      50          NaN
# 10 2023-01-17     Grocery           Chocolate     100          UPI
# 11 2023-01-17        Food          Restaurant     780         Card
# 12 2023-01-18  Essentials            Food Oil     120          NaN
# ...

# %%
df.shape
# Out:
# (29, 5)

# %%
df
# Out:
#          Date    Category       Sub-Category   Amount Payment Mode
# 0  2023-01-01     Grocery             Grocery      30         Cash
# 1  2023-01-02        Food          Restaurant     890          UPI
# 3  2023-01-06  Essentials               Diary     120          UPI
# 4  2023-01-06  Essentials             Perfume    1500         Cash
# 5  2023-01-09     Grocery  Fruits and Veggies     456         Cash
# 6  2023-01-10       Bills          House Rent   16000          UPI
# 7  2023-01-10     Grocery      Tomato KetchUp      70          UPI
# 8  2023-01-12        Food                Chai      15          UPI
# 10 2023-01-17     Grocery           Chocolate     100          UPI
# 11 2023-01-17        Food          Restaurant     780         Card
# 13 2023-01-18        Food              Zomato     230          UPI
# 14 2023-01-19     Grocery                Milk      26          UPI
# 15 2023-01-20  Essentials             Shampoo     780          UPI
# ...

# %%
a =np.sum(df["Amount"])
print(a)

b = np.average(df["Amount"])
print(b)

c = np.mean(df["Amount"])
print(c)
# Out:
# 28722
# 1148.88
# 1148.88
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[75], line 10
#       7 c = np.mean(df["Amount"])
#       8 print(c)
# ---> 10 e = np.count(df["Payment Mode"])
#
# File c:\Users\IRSHAD ANSARI\miniconda3\Lib\site-packages\numpy\__init__.py:428, in __getattr__(attr)
#     425     import numpy.char as char
#     426     return char.chararray
# --> 428 raise AttributeError("module {!r} has no attribute "
#     429                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'count'

# %%
df.isnull().sum()
# Out:
# Date             0
# Category         0
# Sub-Category     0
# Amount           0
# Payment Mode     4
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (25, 5)

# %%
df
dff = pd.DataFrame(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 0 to 28
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           25 non-null     datetime64[ns]
#  1   Category       25 non-null     object
#  2   Sub-Category   25 non-null     object
#  3   Amount         25 non-null     int64
#  4   Payment Mode   25 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 1.2+ KB

# %%
plt.bar(dff, x="Category", y ="Payment Mode")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 plt.bar(dff, x="Category", y ="Payment Mode")
#
# TypeError: bar() got multiple values for argument 'x'
