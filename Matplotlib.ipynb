# %% [markdown]
# Bar Chart🗃️😴😍

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
y = [98,67,88,95,88]
x = ["Part1","Part2","Part3","Part4","Part5"]

colors = ["Red","blue","green","yellow","pink"]
plt.bar(x,y, color = colors, edgecolor = "black")
plt.xlabel("Parts of Harry Potter", fontsize = 15)
plt.ylabel("Popularity", fontsize = 15)
plt.title("Popularity of Different Parts of Harry Potter", fontsize = 20 )
plt.savefig("bar.png")
plt.show()

# %%
data = pd.read_excel("C:/Users/IRSHAD ANSARI/Downloads/expense3.xlsx")

df = pd.DataFrame(data)
print(df)
grouped_by = df.groupby("Payment Mode")["Amount"].sum()
print(grouped_by)
plt.bar(grouped_by.index,grouped_by.values)
plt.show()
# Out:
#          Date    Category       Sub-Category   Amount Payment Mode
# 0  2023-01-01     Grocery             Grocery      30         Cash
# 1  2023-01-02        Food          Restaurant     890          UPI
# 2  2023-01-04         123              Zomato     257          NaN
# 3  2023-01-06  Essentials               Diary     120          UPI
# 4  2023-01-06  Essentials             Perfume    1500         Cash
# 5  2023-01-09     Grocery  Fruits and Veggies     456         Cash
# 6  2023-01-10       Bills          House Rent   16000          UPI
# 7  2023-01-10     Grocery      Tomato KetchUp      70          UPI
# 8  2023-01-12        Food                Chai      15          UPI
# 9  2023-01-15  Essentials      Salt and Sugar      50          NaN
# 10 2023-01-17     Grocery           Chocolate     100          UPI
# 11 2023-01-17        Food          Restaurant     780         Card
# 12 2023-01-18  Essentials            Food Oil     120          NaN
# ...

# %% [markdown]
# Line Plot🗃️😍📁

# %%
x = ["Day1","Day2","Day3","Day4","Day5"]
y = [300,420,250,230,400]
y1 = [500,450,300,250,320]

plt.plot(x,y, marker = "s", ls = ":", color = "red", label = "Week1" )
plt.plot(x,y1, marker = "^", ls = "--", color = "green", label = "Week2")
plt.legend()

plt.show()

# %%
data = pd.read_excel("expense3.xlsx")
df = pd.DataFrame(data)
grouped_by = df.groupby("Category")["Amount"].sum()
print(grouped_by)
print(df)
# Out:
# Category
# 123             257
# Bills         18724
# Clothes        2890
# Essentials     4485
# Food           2765
# Grocery        1028
# Name: Amount, dtype: int64
#          Date    Category       Sub-Category   Amount Payment Mode
# 0  2023-01-01     Grocery             Grocery      30         Cash
# 1  2023-01-02        Food          Restaurant     890          UPI
# 2  2023-01-04         123              Zomato     257          NaN
# 3  2023-01-06  Essentials               Diary     120          UPI
# 4  2023-01-06  Essentials             Perfume    1500         Cash
# 5  2023-01-09     Grocery  Fruits and Veggies     456         Cash
# 6  2023-01-10       Bills          House Rent   16000          UPI
# 7  2023-01-10     Grocery      Tomato KetchUp      70          UPI
# 8  2023-01-12        Food                Chai      15          UPI
# 9  2023-01-15  Essentials      Salt and Sugar      50          NaN
# 10 2023-01-17     Grocery           Chocolate     100          UPI
# ...

# %%
plt.plot(df["Date"],df["Amount"])
plt.show()

# %% [markdown]
# Scatter Plot😍📁🗃️

# %%
x = np.random.randint(1,10,50)
y = np.random.randint(10,100,50)
color = np.random.randint(10,100,50)
size = np.random.randint(10,100,50)
plt.savefig("scatter.png")

plt.scatter(x,y, marker= "*", cmap = "flag_r", c = color, s = size)
plt.savefig("scatter.png")
plt.colorbar()
plt.show()

# %%
data = pd.read_excel("ESD.xlsx")

df = pd.DataFrame(data)
df
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
plt.scatter(df["Age"],df["EEID"])
plt.show()

# %% [markdown]
# Pie Chart🗃️😍📁

# %%
brands = ["Oneplus","Apple","Samsung","Vivo","Nokia"]
popularity = [22,35,30,10,2]
c = ["red","blue","green","yellow","pink"]

plt.pie(popularity, labels = brands , colors= c, shadow= True, autopct= "%.f")
plt.savefig("pie.png", facecolor = "grey")
plt.show()

# %%
data = pd.read_excel("C:/Users/IRSHAD ANSARI/Downloads/expense3.xlsx")
df = pd.DataFrame(data)
print(df)
grouped_by = df.groupby("Payment Mode")["Amount"].sum()
print(grouped_by)
# Out:
#          Date    Category       Sub-Category   Amount Payment Mode
# 0  2023-01-01     Grocery             Grocery      30         Cash
# 1  2023-01-02        Food          Restaurant     890          UPI
# 2  2023-01-04         123              Zomato     257          NaN
# 3  2023-01-06  Essentials               Diary     120          UPI
# 4  2023-01-06  Essentials             Perfume    1500         Cash
# 5  2023-01-09     Grocery  Fruits and Veggies     456         Cash
# 6  2023-01-10       Bills          House Rent   16000          UPI
# 7  2023-01-10     Grocery      Tomato KetchUp      70          UPI
# 8  2023-01-12        Food                Chai      15          UPI
# 9  2023-01-15  Essentials      Salt and Sugar      50          NaN
# 10 2023-01-17     Grocery           Chocolate     100          UPI
# 11 2023-01-17        Food          Restaurant     780         Card
# 12 2023-01-18  Essentials            Food Oil     120          NaN
# ...

# %%
c = ["Red","Green","Yellow"]
plt.pie(grouped_by.values, labels= grouped_by.index, colors = c, shadow=True , autopct= "%.2f")
plt.show()

# %% [markdown]
# Box Plot🗃️😍📁

# %%
l = [25,46,57,25,45,13,29,39,46,99,22,12,14,16,55,6,46,52,55,78]
print(np.median(l))

plt.boxplot(l)
plt.show()
# Out:
# 42.0

# %%
s = [1,3,4,7,12,2,8,9,24]
s2 = [2,3,4,6,3,5,7,3,6]

values = (s,s2)
plt.boxplot(values)
plt.show()

# %%
data = pd.read_excel("C:/Users/IRSHAD ANSARI/Downloads/ESD.xlsx")

df = pd.DataFrame(data)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data = pd.read_excel("C:/Users/IRSHAD ANSARI/Downloads/ESD.xlsx")
#       3 df = pd.DataFrame(data)
#       4 df
#
# File c:\Users\IRSHAD ANSARI\miniconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
# ...

# %%
plt.boxplot(df["Annual Salary"])
plt.show()

# %% [markdown]
# Histogram Plot🗃️😍📁

# %%
x = [30,40,68,27,47,59,47,88,44,23,44,66,66,33,5,2,5,50,12,17,16,16,16]


plt.hist(x, bins=20, color= "Yellow", edgecolor = "Red")
plt.show()

# %%
data = pd.read_excel("C:/Users/IRSHAD ANSARI/Downloads/ESD.xlsx")

df = pd.DataFrame(data)
df
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
plt.hist(df["Age"], bins= 20, color = "Pink" , edgecolor = "black")
plt.show()

# %% [markdown]
# Violin Plot😍🗃️🤗

# %%
z = [20,30,40,50,0,30,40,40,30,30,70,80,75,80,82,88,40,20]

plt.violinplot(z, showmedians= True)
plt.show()

# %%
data = pd.read_excel("C:/Users/IRSHAD ANSARI/Downloads/ESD.xlsx")
df = pd.DataFrame(data)

plt.violinplot(df["Age"], showmedians=True)
plt.show()

# %%
plt.violinplot(df["Annual Salary"], showmeans=True)
plt.show()

# %% [markdown]
# Stem Plot😍🗃️🤗

# %%
a = [10,40,20,40,20,40,20,40,60,70,50,40]

plt.stem(a, linefmt=":", markerfmt= "D" , bottom=5)
plt.show()

# %%
data = pd.read_excel("C:/Users/IRSHAD ANSARI/Downloads/ESD.xlsx")
df = pd.DataFrame(data)

df2 = pd.DataFrame(df.head(50))

plt.stem(df2["Age"])
plt.plot(df2["Age"])
plt.show()

# %% [markdown]
# Stack Plot🤗🗃️😍

# %%
days = [1,2,3,4,5,6,7]

NOP1 = [5,10,30,20,35,50,60]
NOP2 = [40,50,25,60,50,80,85]
NOP3 = [8,15,25,35,60,75,95]

plt.stackplot(days, NOP1, NOP2, NOP3, colors= ["Green","Red","Yellow"], labels = ["Week1","Week2","Week3"])
plt.legend()
plt.show()

# %% [markdown]
# Step Plot🗃️😍📁

# %%
x = ["Day1","Day2","Day3","Day4","Day5"]
y = [20,40,25,80,40,]

plt.step(x,y, where= "post", marker = "o", color = "red")
plt.show()

# %%
data = pd.read_excel("D:/DATA FOR PRACTICE/expense3.xlsx")
df = pd.DataFrame(data)
print(df)
group = df.groupby("Category").agg({"Amount":"sum"})
print(group)
# Out:
#          Date    Category       Sub-Category   Amount Payment Mode
# 0  2023-01-01     Grocery             Grocery      30         Cash
# 1  2023-01-02        Food          Restaurant     890          UPI
# 2  2023-01-04         123              Zomato     257          NaN
# 3  2023-01-06  Essentials               Diary     120          UPI
# 4  2023-01-06  Essentials             Perfume    1500         Cash
# 5  2023-01-09     Grocery  Fruits and Veggies     456         Cash
# 6  2023-01-10       Bills          House Rent   16000          UPI
# 7  2023-01-10     Grocery      Tomato KetchUp      70          UPI
# 8  2023-01-12        Food                Chai      15          UPI
# 9  2023-01-15  Essentials      Salt and Sugar      50          NaN
# 10 2023-01-17     Grocery           Chocolate     100          UPI
# 11 2023-01-17        Food          Restaurant     780         Card
# 12 2023-01-18  Essentials            Food Oil     120          NaN
# ...

# %%
#where marker end.
#plt.step(group.index, group["Amount"])
#plt.show()

# %% [markdown]
# Legend in Matplotlib😍📁🗃️

# %%
x = [1,2,3,4,5]
y = [45,70,35,68,25]
y1 = [40,60,15,60,14]
y2 = [11,30,55,60,19]
y3 = [11,40,45,80,50]

plt.plot(x,y, label = "male", marker = "o")
plt.plot(x,y1, label = "female" , marker = "^")
plt.plot(x,y2, label = "Kids" , marker = "+")
plt.legend()
plt.plot(x,y3)
plt.show()

# %%
x = [1,2,3,4,5]
y = [45,70,35,68,25]
y1 = [40,60,15,60,14]
y2 = [11,30,55,60,19]
y3 = [11,40,45,80,50]

plt.plot(x,y, label = "male", marker = "o")
plt.plot(x,y1, label = "female" , marker = "^")
plt.plot(x,y2, label = "Kids" , marker = "+")
plt.plot(x,y3, label = "Blanks")
plt.legend(bbox_to_anchor = (0.8,1.1), ncols= 2, labelspacing = 1)
plt.plot(x,y3)
plt.show()

# %% [markdown]
# Sub Plot🗃️😍🗃️

# %%
x = [1,2,3,4,5]
y = [20,25,50,27,30]
plt.subplot(2,3,2)  #rows, column, chart no
plt.bar(x, y)
plt.suptitle("Employee Data")
plt.show()

x1 = [5,6,7,8,9]
y2 = [67,50,66,56,82]
plt.subplot(2,3,2)
plt.scatter(x1,y2)
plt.show()

x1 = [2,4,6,8,10]
y2 = [57,50,66,56,22]
plt.subplot(2,3,3)
plt.step(x1,y2)
plt.show()

# %% [markdown]
# Save Chart On your Desk Top in Matplotlib😍😍🗃️

# %%
#Write (plt.savefig("pie/bar,scatter.png"))
